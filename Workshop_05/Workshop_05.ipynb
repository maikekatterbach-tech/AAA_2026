# %% [markdown]
# # Deep Learning - Part 1

# %% [markdown]
# #### Content
#
# 1. Tensors and how to work with Pytorch
# 2. Autograd in Pytorch
# 3. Solving a simple image classification using neural networks coded with Pytorch

# %% [markdown]
# #### Installing Pytorch

# %% [markdown]
# ```pip install torch```

# %% [markdown]
# ## 1. Tensors
# Tensors are similar to NumPy’s ndarrays, with the addition being that Tensors can also be used on a GPU to accelerate computing.
#
# ### 1.1 Creating Tensors from data
# Tensors can be created from Python lists with the `torch.Tensor()` function.

# %%
import torch
# Example with 1-D data
data = [1.0, 2.0, 3.0]
tensor = torch.Tensor(data)
print("Example with 1-D data")
print(tensor)

# Example with 2-D data
data = [[1., 2., 3.], [4., 5., 6]]
tensor = torch.Tensor(data)
print("\nExample with 2-D data")
print(tensor)

# Example with 3-D data
data = [[[1.,2.], [3.,4.]],
        [[5.,6.], [7.,8.]]]
tensor = torch.Tensor(data)
print("\nExample with 3-D data")
print(tensor)
# Out:
# Example with 1-D data
# tensor([1., 2., 3.])
#
# Example with 2-D data
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])
#
# Example with 3-D data
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])

# %% [markdown]
# ### 1.2 Initializing an empty Tensor
# An uninitialized matrix is declared, but does not contain definite known values before it is used. When an uninitialized matrix is created, whatever values were in the allocated memory at the time will appear as the initial values.

# %%
# Construct a 2x3 matrix, uninitialized
x = torch.empty(2, 3)
print(x)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %% [markdown]
# ### 1.3 Randomly initialized Tensor
#
# 1.3 Randomly initialized Tensor

# %%
x = torch.rand(2, 3)
print(x)
# Out:
# tensor([[0.0338, 0.8657, 0.6639],
#         [0.1153, 0.8044, 0.9407]])

# %% [markdown]
# ### 1.4 Tensor with zeros or ones

# %%
# Create a matrix of all zeros
x = torch.zeros(2, 3)
print("Matrix of zeros")
print(x)

# Create a matrix of all zeros and explicitly set data type to be long int
x = torch.zeros(2, 3, dtype=torch.long)
print("\nMatrix of zeros typecasted to long")
print(x)

x = torch.ones(2, 3, dtype=torch.long)
print("\nMatrix of ones typecasted to long")
print(x)
# Out:
# Matrix of zeros
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
#
# Matrix of zeros typecasted to long
# tensor([[0, 0, 0],
#         [0, 0, 0]])
#
# Matrix of ones typecasted to long
# tensor([[1, 1, 1],
#         [1, 1, 1]])

# %% [markdown]
# ### 1.5 Create Tensor based on existing Tensor

# %%
x = x.new_ones(2, 3, dtype=torch.double)      # new_* methods take in sizes
print(x)

x = torch.randn_like(x, dtype=torch.float)    # override dtype!
print(x)                                      # result has the same size
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], dtype=torch.float64)
# tensor([[-1.7702,  1.5230, -0.9516],
#         [-1.8833, -0.0492,  2.3560]])

# %% [markdown]
# ### 1.6 Size of a Tensor
# `torch.Size` is in fact a tuple, so it supports all tuple operations.

# %%
# Example with 1-D data
data = [1.0, 2.0, 3.0]
tensor = torch.Tensor(data)
print("Example with 1-D data")
print(tensor)
print(tensor.size())

# Example with 2-D data
data = [[1., 2., 3.], [4., 5., 6]]
tensor = torch.Tensor(data)
print("\nExample with 2-D data")
print(tensor)
print(tensor.size())

# Example with 3-D data
data = [[[1.,2.], [3.,4.]],
        [[5.,6.], [7.,8.]]]
tensor = torch.Tensor(data)
print("\nExample with 3-D data")
print(tensor)
print(tensor.size())
# Out:
# Example with 1-D data
# tensor([1., 2., 3.])
# torch.Size([3])
#
# Example with 2-D data
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])
# torch.Size([2, 3])
#
# Example with 3-D data
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])
# torch.Size([2, 2, 2])

# %% [markdown]
# ### 1.7 Operations with Tensors
# Most operations are very similar to NumPy.

# %%
# Addition
x = torch.Tensor([ 1., 2., 3. ])
y = torch.Tensor([ 4., 5., 6. ])

# using arithmetic operation
z = x + y
print(z)

# using method
print(torch.add(x, y))

# using method and providing an output tensor as argument
output = torch.empty(2, 3)
torch.add(x, y, out=output)
print(output)
# Out:
# tensor([5., 7., 9.])
# tensor([5., 7., 9.])
# tensor([5., 7., 9.])
# /var/folders/8d/n4bdnzg12hjcvm1y4phfmzbc0000gn/T/ipykernel_32475/1344850032.py:14: UserWarning: An output with one or more elements was resized since it had shape [2, 3], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:38.)
#   torch.add(x, y, out=output)

# %%
# In-place addition

x = torch.Tensor([ 1., 2., 3. ])
y = torch.Tensor([ 4., 5., 6. ])

y.add_(x)
print(y)
# Out:
# tensor([5., 7., 9.])

# %% [markdown]
# Any operation that mutates a tensor in-place is post-fixed with an underscore `_`. For example: `x.copy_(y)`, `x.t_()`, will change `x`.
#
# See [the PyTorch official documentation](http://pytorch.org/docs/torch.html) for a complete list of the massive number of operations available to you.  They expand beyond just mathematical operations.

# %%
# Indexing

x = torch.Tensor([[1., 2., 3.], [4., 5., 6]])
print(x[1, :]) # Gets column with index 1
# Out:
# tensor([4., 5., 6.])

# %% [markdown]
# ### 1.8 Reshaping Tensors

# %%
x = torch.randn(4, 4)
y = x.view(16)
z = x.view(-1, 2)  # the size -1 is inferred from other dimensions
print(x.size(), y.size(), z.size())
# Out:
# torch.Size([4, 4]) torch.Size([16]) torch.Size([8, 2])

# %%
x.reshape(-1,8)
# Out:
# tensor([[ 0.4163,  0.5201,  0.6268,  0.8544, -0.1321,  0.0924,  0.6216, -0.9556],
#         [-0.1592, -0.0358,  1.1039, -0.4663, -1.3020,  1.3934, -0.2338, -0.5505]])

# %%
x = torch.randn(1)
print(x)
print(x.item())
# Out:
# tensor([-0.2515])
# -0.2515397369861603

# %% [markdown]
# ### 1.9 Converting to and from NumPy
# Converting a Torch Tensor to a NumPy array and vice versa is a breeze.
#
# The Torch Tensor and NumPy array will **share their underlying memory locations** (if the Torch Tensor is on CPU), and **changing one will change the other**.

# %%
a = torch.ones(5)
print("Original a:", a)

b = a.numpy()
print("Original b:", b)

a.add_(1)
print("New a:", a)
print("New b:", b)
# Out:
# Original a: tensor([1., 1., 1., 1., 1.])
# Original b: [1. 1. 1. 1. 1.]
# New a: tensor([2., 2., 2., 2., 2.])
# New b: [2. 2. 2. 2. 2.]

# %%
import numpy as np
a = np.ones(5)
b = torch.from_numpy(a) # or b = torch.tensor(a) but you cannot dot this: """a.tensor()"""
np.add(a, 1, out=a)
print(a)
print(b)
# Out:
# [2. 2. 2. 2. 2.]
# tensor([2., 2., 2., 2., 2.], dtype=torch.float64)

# %% [markdown]
# #### Chaging the type of tensors

# %%
x = torch.tensor([1, 2, 3])         # default: int64
x = x.to(torch.float32)            # convert to float32

# %%
x = x.type(torch.FloatTensor)      # convert to float32

# %%
x = x.float()      # to float32  
x = x.double()     # to float64  
x = x.int()        # to int32  
x = x.long()       # to int64  
x = x.bool()       # to bool

# %% [markdown]
# ### 1.10 GPU Tensors
#
# Tensors can be moved onto any device using the `.to` method.

# %%
# Try to run this cell with both GPU support and without
print("CUDA available?", torch.cuda.is_available())
print("Metal (Apple Silicon) available?", torch.mps.is_available())

# We will use ``torch.device`` objects to move tensors in and out of GPU
if torch.cuda.is_available() or torch.mps.is_available():
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps")  # a CUDA or MPS device object
    x = torch.Tensor([1.0, 2.0, 3.0])
    y = torch.ones_like(x, device=device, dtype=torch.float)  # directly create a tensor on GPU or MPS
    x = x.to(device)                       # or just use strings ``.to("cuda")`` or ``.to("mps")``
    z = x + y
    print(z)
    print(z.to("cpu", torch.float))       # ``.to`` can also change dtype together!
# Out:
# CUDA available? False
# Metal (Apple Silicon) available? True
# tensor([2., 3., 4.], device='mps:0')
# tensor([2., 3., 4.])

# %%
# You cannot do the operaions on tensors on different devices
a = torch.tensor([1.0], device='mps')  # or 'cuda' if you have a CUDA device
b = torch.tensor([2.0], device='cpu')

# Move b to MPS (Apple Silicon)
b = b.to('mps')
c = a + b

# %% [markdown]
# ## 2. Autograd: Automatic Differentiation
#
# The autograd package provides automatic differentiation for all operations on Tensors. It is a define-by-run framework, which means that your backprop is defined by how your code is run, and that every single iteration can be different.
#
# ``torch.Tensor`` is the central class of the package. If you set its attribute
# ``.requires_grad`` as ``True``, it **starts to track all operations on it**. When
# you finish your computation you can call ``.backward()`` and have **all the
# gradients computed automatically**. The gradient for this tensor will be
# accumulated into ``.grad`` attribute.
#
# To **stop a tensor from tracking history**, you can call ``.detach()`` to detach
# it from the computation history, and to prevent future computation from being
# tracked.
#
# To **prevent tracking history (and using memory)**, you can also wrap the code block
# in ``with torch.no_grad():``. This can be particularly helpful when evaluating a
# model because the model may have trainable parameters with `requires_grad=True`,
# but for which we don't need the gradients.

# %%
x = torch.ones(2, 2, requires_grad=True)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)

# %%
y = x + 2
print(y)

# y was created as a result of an operation, so it has a grad_fn.
# Out:
# tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)

# %%
z = y * y * 3
out = z.mean()

print(z, out)
# Out:
# tensor([[27., 27.],
#         [27., 27.]], grad_fn=<MulBackward0>) tensor(27., grad_fn=<MeanBackward0>)

# %% [markdown]
# ``.requires_grad_( ... )`` changes an existing Tensor's ``requires_grad``
# flag in-place. The input flag defaults to ``False`` if not given.

# %%
a = torch.randn(2, 2)
a = ((a * 3) / (a - 1))
print(a.requires_grad)
a.requires_grad_(True)
print(a.requires_grad)
b = (a * a).sum()
print(b.grad_fn)
# Out:
# False
# True
# <SumBackward0 object at 0x10a0e7ca0>

# %% [markdown]
# #### Let us consider a complete example now.
# We aim to calculate $\frac{\partial out}{\partial x_i} $
#
# Let $out = \frac{1}{4}\sum_i z_i$,
# $z_i = 3(x_i+2)^2$
# and $z_i\bigr\rvert_{x_i=1} = 27$.
# Therefore,
# $\frac{\partial out}{\partial x_i} = \frac{1}{4}\frac{\partial z_i}{\partial x_i} = \frac{1}{4}.3.2(x_i+2) = \frac{3}{2}(x_i+2)$,
#  hence
# $\frac{\partial out}{\partial x_i}\bigr\rvert_{x_i=1} = \frac{9}{2} = 4.5$.

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x + 2
z = y * y * 3
out = z.mean()

grads = out.backward()
print(x.grad)
# Out:
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])

# %% [markdown]
# Mathematically, if you have a vector valued function $\vec{y}=f(\vec{x})$, then the gradient of $\vec{y}$ with respect to $\vec{x}$ is a Jacobian matrix:
#
# $$
# \begin{split}J=\left(\begin{array}{ccc}
#  \frac{\partial y_{1}}{\partial x_{1}} & \cdots & \frac{\partial y_{1}}{\partial x_{n}}\\
#  \vdots & \ddots & \vdots\\
#  \frac{\partial y_{m}}{\partial x_{1}} & \cdots & \frac{\partial y_{m}}{\partial x_{n}}
#  \end{array}\right)\end{split}
# $$
#
# Generally speaking, `torch.autograd` is an engine for computing vector-Jacobian product. That is, given any vector $v=\left(\begin{array}{cccc} v_{1} & v_{2} & \cdots & v_{m}\end{array}\right)^{T}$, compute the product $v^{T}\cdot J$. If $v$ happens to be the gradient of a scalar function $l=g\left(\vec{y}\right)$, that is, $v=\left(\begin{array}{ccc}\frac{\partial l}{\partial y_{1}} & \cdots & \frac{\partial l}{\partial y_{m}}\end{array}\right)^{T}$, then by the chain rule, the vector-Jacobian product would be the gradient of $l$ with respect to $\vec{x}$:
#
# $$
# \begin{split}J^{T}\cdot v=\left(\begin{array}{ccc}
#  \frac{\partial y_{1}}{\partial x_{1}} & \cdots & \frac{\partial y_{m}}{\partial x_{1}}\\
#  \vdots & \ddots & \vdots\\
#  \frac{\partial y_{1}}{\partial x_{n}} & \cdots & \frac{\partial y_{m}}{\partial x_{n}}
#  \end{array}\right)\left(\begin{array}{c}
#  \frac{\partial l}{\partial y_{1}}\\
#  \vdots\\
#  \frac{\partial l}{\partial y_{m}}
#  \end{array}\right)=\left(\begin{array}{c}
#  \frac{\partial l}{\partial x_{1}}\\
#  \vdots\\
#  \frac{\partial l}{\partial x_{n}}
#  \end{array}\right)\end{split}
# $$
#
# (Note that $v^{T}\cdot J$ gives a row vector which can be treated as a column vector by taking $J^{T}\cdot v$.)
#
# This characteristic of vector-Jacobian product makes it very convenient to feed external gradients into a model that has non-scalar output.

# %% [markdown]
# You can also stop autograd from tracking history on Tensors with `.requires_grad=True` either by wrapping the code block in with `torch.no_grad()`:

# %%
print(x.requires_grad)
print((x ** 2).requires_grad)

with torch.no_grad():
    print((x ** 2).requires_grad)
# Out:
# True
# True
# False

# %% [markdown]
# ### 3. Problem to solve: Classify hand written digits using the MNIST dataset

# %% [markdown]
# It’s a set of 60,000 training
# images, plus 10,000 test images, assembled by the National Institute of Standards and
# Technology (the NIST in MNIST) in the 1980s. You can think of “solving” MNIST as the
# “Hello World” of deep learning—it’s what you do to verify that your algorithms are
# working as expected.

# %% [markdown]
# <img src="resources/img1.png" width="400">

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 3.1 Define Hyperparameters and Transformations

# %%
batch_size = 64
num_epochs = 10
learning_rate = 0.01

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # Mean and Std of MNIST dataset
])

# %% [markdown]
# ### 3.2 Load and Prepare the Dataset
#
# The MNIST dataset is loaded for both training and testing. We use DataLoader to manage batching and shuffling of data during training.

# %%
train_dataset = datasets.MNIST(root='.', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='.', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %% [markdown]
# ### 3.3 Define the Neural Network Model
#
# We define a simple feedforward neural network with two fully connected layers. The first layer takes the flattened image (28x28 pixels) and outputs 512 features. The second layer outputs 10 classes (digits 0-9).

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)  # Flatten the image
        x = F.relu(self.fc1(x))  # ReLU activation
        x = self.fc2(x)  # Output layer
        return x

# %%
# an alternative
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.relu(self.fc1(x))  # Use the module
        x = self.fc2(x)
        return x

# %% [markdown]
# ### 3.4 Define the Loss Function, Optimizer, and Model Instance
#
# We use CrossEntropyLoss as the loss function for multi-class classification. The optimizer used is Stochastic Gradient Descent (SGD).

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.mps.is_available() else "cpu")
model = Net().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### 3.5 Define the Training and Test Loops
#
# The training loop processes the batches, computes the gradients, and updates the model parameters. The test loop evaluates the model on the test dataset.

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, 1)
    return torch.sum(preds == labels).item() / len(labels)

def train(model, device, train_loader, criterion, optimizer, epoch):
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += accuracy(outputs, labels)
        if (i + 1) % 200 == 0:
            print(f'Epoch {epoch}, Batch {i+1}, Loss: {running_loss / 200:.4f}, Accuracy: {running_acc / 200:.4f}')
            running_loss = 0.0
            running_acc = 0.0

def test(model, device, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    test_acc = 0.0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            test_acc += accuracy(outputs, labels)
    print(f'Test Loss: {test_loss / len(test_loader):.4f}, Test Accuracy: {test_acc / len(test_loader):.4f}')

# %% [markdown]
# ### 3.6 Train, Test, and Visualize Results
#
# The model is trained for a set number of epochs and then tested. Additionally, a few sample predictions are visualized using matplotlib.

# %%
for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader, criterion, optimizer, epoch)
    test(model, device, test_loader, criterion)

# Visualize sample images with predictions
samples, labels = next(iter(test_loader))
samples = samples.to(device)
outputs = model(samples)
_, preds = torch.max(outputs, 1)

samples = samples.cpu().numpy()
fig, axes = plt.subplots(3, 3, figsize=(8, 8))
for i, ax in enumerate(axes.ravel()):
    ax.imshow(samples[i].squeeze(), cmap='gray')
    ax.set_title(f'Label: {labels[i]}, Prediction: {preds[i]}')
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Batch 200, Loss: 1.1114, Accuracy: 0.7547
# Epoch 1, Batch 400, Loss: 0.4925, Accuracy: 0.8748
# Epoch 1, Batch 600, Loss: 0.3869, Accuracy: 0.8949
# Epoch 1, Batch 800, Loss: 0.3591, Accuracy: 0.8984
# Test Loss: 0.3040, Test Accuracy: 0.9150
# Epoch 2, Batch 200, Loss: 0.3162, Accuracy: 0.9098
# Epoch 2, Batch 400, Loss: 0.2951, Accuracy: 0.9163
# Epoch 2, Batch 600, Loss: 0.2823, Accuracy: 0.9197
# Epoch 2, Batch 800, Loss: 0.2755, Accuracy: 0.9191
# Test Loss: 0.2498, Test Accuracy: 0.9307
# Epoch 3, Batch 200, Loss: 0.2443, Accuracy: 0.9320
# Epoch 3, Batch 400, Loss: 0.2399, Accuracy: 0.9321
# Epoch 3, Batch 600, Loss: 0.2378, Accuracy: 0.9313
# Epoch 3, Batch 800, Loss: 0.2322, Accuracy: 0.9334
# Test Loss: 0.2111, Test Accuracy: 0.9394
# Epoch 4, Batch 200, Loss: 0.2127, Accuracy: 0.9413
# Epoch 4, Batch 400, Loss: 0.2183, Accuracy: 0.9396
# Epoch 4, Batch 600, Loss: 0.2052, Accuracy: 0.9436
# Epoch 4, Batch 800, Loss: 0.1980, Accuracy: 0.9440
# Test Loss: 0.1858, Test Accuracy: 0.9468
# Epoch 5, Batch 200, Loss: 0.1902, Accuracy: 0.9470
# Epoch 5, Batch 400, Loss: 0.1796, Accuracy: 0.9500
# Epoch 5, Batch 600, Loss: 0.1737, Accuracy: 0.9516
# Epoch 5, Batch 800, Loss: 0.1765, Accuracy: 0.9503
# Test Loss: 0.1686, Test Accuracy: 0.9505
# Epoch 6, Batch 200, Loss: 0.1701, Accuracy: 0.9518
# Epoch 6, Batch 400, Loss: 0.1528, Accuracy: 0.9570
# Epoch 6, Batch 600, Loss: 0.1647, Accuracy: 0.9554
# Epoch 6, Batch 800, Loss: 0.1555, Accuracy: 0.9566
# Test Loss: 0.1516, Test Accuracy: 0.9563
# Epoch 7, Batch 200, Loss: 0.1588, Accuracy: 0.9566
# Epoch 7, Batch 400, Loss: 0.1495, Accuracy: 0.9570
# Epoch 7, Batch 600, Loss: 0.1383, Accuracy: 0.9621
# Epoch 7, Batch 800, Loss: 0.1369, Accuracy: 0.9619
# Test Loss: 0.1398, Test Accuracy: 0.9595
# Epoch 8, Batch 200, Loss: 0.1343, Accuracy: 0.9643
# Epoch 8, Batch 400, Loss: 0.1304, Accuracy: 0.9633
# Epoch 8, Batch 600, Loss: 0.1329, Accuracy: 0.9623
# Epoch 8, Batch 800, Loss: 0.1344, Accuracy: 0.9631
# Test Loss: 0.1296, Test Accuracy: 0.9615
# Epoch 9, Batch 200, Loss: 0.1276, Accuracy: 0.9652
# Epoch 9, Batch 400, Loss: 0.1250, Accuracy: 0.9652
# Epoch 9, Batch 600, Loss: 0.1207, Accuracy: 0.9664
# Epoch 9, Batch 800, Loss: 0.1098, Accuracy: 0.9704
# Test Loss: 0.1228, Test Accuracy: 0.9640
# Epoch 10, Batch 200, Loss: 0.1197, Accuracy: 0.9672
# Epoch 10, Batch 400, Loss: 0.1138, Accuracy: 0.9684
# Epoch 10, Batch 600, Loss: 0.1109, Accuracy: 0.9691
# Epoch 10, Batch 800, Loss: 0.1078, Accuracy: 0.9718
# Test Loss: 0.1140, Test Accuracy: 0.9666

# %% [markdown]
# ### Coding Task: What if we want outputs as probabilities?
# Think back to the lecture: What would the output need to look like in light of the possible classes? How to achieve this with torch?
